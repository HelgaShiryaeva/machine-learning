# %% [markdown]
# # Test demo

# %%
# %matplotlib inline

from preprocessing import utils
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 10]

folder_path = 'C:\\Users\\helga_sh\\Downloads\\EnglishImg\\English\\Img\\GoodImg\\Bmp'
imsize = 64
rows, columns = 5, 5

# %%
image_to_label = utils.load_data(folder_path, imsize)
# Out:
# ...
# 100%|██████████| 62/62 [00:04<00:00, 15.40it/s]s]
# Loaded successfully

# %%
utils.plot_random_samples(image_to_label, rows, columns)
